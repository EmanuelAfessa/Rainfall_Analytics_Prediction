# %% [markdown]
# # Univariate time series forecasting

# %% [markdown]
# ## 1. import data

# %%
# import libraries 
import pandas as pd
import plotly.express as px
import pycaret
from pycaret.time_series import *
from pandas.io.formats import style

# %%
# import multivariate data
data = pd.read_csv('data/proc_data/weatherwcity.csv')
data['Date'] = pd.to_datetime(data['Date.Full'])
data = data[['Date','Precipitation']]

# %%
# get only date and 
data
# Out:
#            Date  Precipitation
# 0    2016-01-03           0.00
# 1    2016-01-10           0.52
# 2    2016-01-17           0.34
# 3    2016-01-24           1.55
# 4    2016-01-31           0.87
# ...         ...            ...
# 9323 2016-12-04           0.01
# 9324 2016-12-11           0.12
# 9325 2016-12-18           0.26
# 9326 2016-12-25           0.04
# 9327 2017-01-01           0.00
#
# [9328 rows x 2 columns]

# %%
s = setup(data, target = 'Precipitation',session_id = 123)
# Out:
# <style type="text/css">
# #T_e4db7_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e4db7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4db7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e4db7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4db7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4db7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e4db7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e4db7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4db7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e4db7_row1_col1" class="data row1 col1" >Precipitation</td>
#     </tr>
#     <tr>
#       <th id="T_e4db7_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# train with pycaret and identify the best model  
best = compare_models(sort = 'MAE')

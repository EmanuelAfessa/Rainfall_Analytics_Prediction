# %% [markdown]
# # Time Series Forecasting _ Basics

# %% [markdown]
# ## 1. Fetch data from air quality

# %%
from ucimlrepo import fetch_ucirepo 
import pandas as pd

# %%
air_quality = fetch_ucirepo(id=360)

# %%
data_features = air_quality.data.features
type(data_features)
# Out:
# pandas.core.frame.DataFrame

# %%
data_features
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     3/10/2004  18:00:00     2.6         1360       150      11.9
# 1     3/10/2004  19:00:00     2.0         1292       112       9.4
# 2     3/10/2004  20:00:00     2.2         1402        88       9.0
# 3     3/10/2004  21:00:00     2.2         1376        80       9.2
# 4     3/10/2004  22:00:00     1.6         1272        51       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352   4/4/2005  10:00:00     3.1         1314      -200      13.5
# 9353   4/4/2005  11:00:00     2.4         1163      -200      11.4
# 9354   4/4/2005  12:00:00     2.4         1142      -200      12.4
# 9355   4/4/2005  13:00:00     2.1         1003      -200       9.5
# 9356   4/4/2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %% [markdown]
# ## 2. Preprocessing & plotting

# %%
data_features.shape
# Out:
# (9357, 16)

# %%
data_features.isna().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
df = data_features
df['DateTime'] = (df.Date) + ' ' + (df.Time)
print (type(df.DateTime[0]))
# Out:
# <class 'str'>

# %%
df.index = df.DateTime

# %%
fig = px.line(data_features, x= "Date", y="T",   title='Temperature Trend')
fig.show()

# %%
fig = px.box(df, y="T")
fig.show()

# %%
data_features['T'].min()
# Out:
# -200.0
